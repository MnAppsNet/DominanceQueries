# %% [markdown]
# ### Prepare Notebook

# %%
# %cd ../
# Out:
# /home/mnapps/DominanceQueries

# %%
from visualize import visualize

# %% [markdown]
# ### Uniform Dataset with 1000 samples and 2 dimensions

# %% [markdown]
# #### Generate Dataset

# %%
# !echo "Generating dataset..."
# !python3 generateDatasets/generateUniformDataset.py -s 1000 -d 2 -o datasets/uniform.s1000.d2.csv -r 41
# Out:
# Generating dataset...
#
# Execution time : 0.003406 sec
# Figure(640x480)

# %% [markdown]
# #### Run spark script

# %%
# !echo "Executing Spark Script..."
# !java -jar DominanceQueries.jar settings.json 0 "uniform.s1000.d2" 4 4
# Out:
# Executing Spark Script...
#  >>>>  Reading settings file : /home/mnapps/DominanceQueries/settings.json
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/mnapps/DominanceQueries/DominanceQueries.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
#  >>>> (0.0000sec) File set for read : /home/mnapps/DominanceQueries/datasets/uniform.s1000.d2.csv
#  >>>> (0.3558sec) Gathering and sorting the data...
#  >>>> (1.1264sec) Execution time : 1.126373864 sec
#  >>>> (1.1267sec) ---
#  >>>> (1.1269sec)
#  >>>> (0.0000sec) Task 1:
# ...

# %% [markdown]
# #### Visualize

# %% [markdown]
# ##### Skyline

# %%
print("Skyline")
visualize("datasets/uniform.s1000.d2.csv", "results/uniform.s1000.d2/task1.csv")
# Out:
# Skyline

# %% [markdown]
# ##### Top 4 points in terms of dominations

# %%
print("Top 4 points in terms of dominations")
visualize("datasets/uniform.s1000.d2.csv", "results/uniform.s1000.d2/task2.csv")
# Out:
# Top 4 points in terms of dominations

# %% [markdown]
# ##### Top 4 points of the skyline in terms of dominations

# %%
print("Top 4 skyline points in terms of dominations")
visualize("datasets/uniform.s1000.d2.csv", "results/uniform.s1000.d2/task3.csv")
# Out:
# Top 4 skyline points in terms of dominations

# %% [markdown]
# ### Conclude execution

# %%
# %cd tests
# Out:
# /home/mnapps/DominanceQueries/tests
